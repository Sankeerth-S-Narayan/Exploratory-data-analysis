# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# use auto-mpg dataset

# %%
mpg_df=pd.read_csv("auto-mpg.csv")

# %%
mpg_df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df_reshape=mpg_df.melt(id_vars="car name")
df_reshape
df_reshape=mpg_df.melt(id_vars="car name",value_vars="cylinders")

df_reshape.head(25)
# Out:
#                         car name   variable  value
# 0      chevrolet chevelle malibu  cylinders      8
# 1              buick skylark 320  cylinders      8
# 2             plymouth satellite  cylinders      8
# 3                  amc rebel sst  cylinders      8
# 4                    ford torino  cylinders      8
# 5               ford galaxie 500  cylinders      8
# 6               chevrolet impala  cylinders      8
# 7              plymouth fury iii  cylinders      8
# 8               pontiac catalina  cylinders      8
# 9             amc ambassador dpl  cylinders      8
# 10           dodge challenger se  cylinders      8
# 11            plymouth 'cuda 340  cylinders      8
# 12         chevrolet monte carlo  cylinders      8
# 13       buick estate wagon (sw)  cylinders      8
# 14         toyota corona mark ii  cylinders      4
# 15               plymouth duster  cylinders      6
# 16                    amc hornet  cylinders      6
# ...

# %%
df_reshape=mpg_df.melt(id_vars="car name",value_vars="cylinders")

df_reshape.head(5)
# Out:
#                     car name   variable  value
# 0  chevrolet chevelle malibu  cylinders      8
# 1          buick skylark 320  cylinders      8
# 2         plymouth satellite  cylinders      8
# 3              amc rebel sst  cylinders      8
# 4                ford torino  cylinders      8

# %%
mpg_df.duplicated(keep=False)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# Length: 398, dtype: bool

# %%
sns.catplot(x="horsepower", y="acceleration",aspect=9, data=mpg_df)

# %%
plt.subplot(2,2,1)
plt.hist(mpg_df['acceleration'],color='r')
plt.subplot(2,2,2)
plt.hist(mpg_df['displacement'],color='b')
plt.subplot(2,2,3)
plt.hist(mpg_df['weight'],color='g')
plt.subplot(2,2,4)
plt.hist(mpg_df['mpg'],color='c')
# Out:
# (array([13., 78., 73., 61., 54., 48., 38., 22.,  5.,  6.]),
#  array([ 9.  , 12.76, 16.52, 20.28, 24.04, 27.8 , 31.56, 35.32, 39.08,
#         42.84, 46.6 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.countplot(x="origin",data=mpg_df)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='count'>
